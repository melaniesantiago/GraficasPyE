# %% [markdown]
# # Probabilidad y Estadística: Ejercicio 13

# %% [markdown]
# ## 13. Meteorología. Los datos siguientes representan las temperaturas promedio en la República Mexicana durante eOctubre de 2010.

# %% [markdown]
# <table>
#   <thead>
#     <tr>
#       <th colspan="8">Temperatura media (°C) octubre 2010</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>27.4</td>
#       <td>29.5</td>
#       <td>23.5</td>
#       <td>32.3</td>
#       <td>29.6</td>
#       <td>24.8</td>
#       <td>34.7</td>
#       <td>23.0</td>
#     </tr>
#     <tr>
#       <td>28.5</td>
#       <td>28.1</td>
#       <td>27.0</td>
#       <td>24.8</td>
#       <td>34.3</td>
#       <td>36.2</td>
#       <td>32.3</td>
#       <td>28.1</td>
#     </tr>
#     <tr>
#       <td>32.1</td>
#       <td>30.5</td>
#       <td>21.6</td>
#       <td>28.7</td>
#       <td>29.9</td>
#       <td>32.5</td>
#       <td>30.7</td>
#       <td>31.4</td>
#     </tr>
#     <tr>
#       <td>31.8</td>
#       <td>33.3</td>
#       <td>26.9</td>
#       <td>26.9</td>
#       <td>29.9</td>
#       <td>29.9</td>
#       <td>31.1</td>
#       <td>26.1</td>
#     </tr>
#   </tbody>
# </table>
