# %% [markdown]
# # Probabilidad y Estadística: Ejercicio 13

# %% [markdown]
# ## 13. Meteorología. Los datos siguientes representan las temperaturas promedio en la República Mexicana durante eOctubre de 2010.

# %% [markdown]
# <table>
#   <thead>
#     <tr>
#       <th colspan="8">Temperatura media (°C) octubre 2010</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>27.4</td>
#       <td>29.5</td>
#       <td>23.5</td>
#       <td>32.3</td>
#       <td>29.6</td>
#       <td>24.8</td>
#       <td>34.7</td>
#       <td>23.0</td>
#     </tr>
#     <tr>
#       <td>28.5</td>
#       <td>28.1</td>
#       <td>27.0</td>
#       <td>24.8</td>
#       <td>34.3</td>
#       <td>36.2</td>
#       <td>32.3</td>
#       <td>28.1</td>
#     </tr>
#     <tr>
#       <td>32.1</td>
#       <td>30.5</td>
#       <td>21.6</td>
#       <td>28.7</td>
#       <td>29.9</td>
#       <td>32.5</td>
#       <td>30.7</td>
#       <td>31.4</td>
#     </tr>
#     <tr>
#       <td>31.8</td>
#       <td>33.3</td>
#       <td>26.9</td>
#       <td>26.9</td>
#       <td>29.9</td>
#       <td>29.9</td>
#       <td>31.1</td>
#       <td>26.1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <table>
#   <thead>
#     <tr>
#       <th>Temperatura (°C)</th>
#       <th>Frecuencia Absoluta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>23.0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>23.5</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>24.8</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>26.1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>26.9</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>27.0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>28.1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>28.5</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>29.5</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>29.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>29.9</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>30.5</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>30.7</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>31.1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>31.4</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>32.1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>32.3</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>32.5</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>33.3</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>34.3</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>34.7</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>36.2</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <table>
#   <thead>
#     <tr>
#       <th>Valor</th>
#       <th>Frecuencia</th>
#       <th>Frecuencia Relativa</th>
#       <th>Frecuencia Relativa Acumulada</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>20.2</td>
#       <td>1</td>
#       <td>0.033</td>
#       <td>0.033</td>
#     </tr>
#     <tr>
#       <td>21.6</td>
#       <td>1</td>
#       <td>0.033</td>
#       <td>0.067</td>
#     </tr>
#     <tr>
#       <td>23.5</td>
#       <td>1</td>
#       <td>0.033</td>
#       <td>0.100</td>
#     </tr>
#     <tr>
#       <td>24.8</td>
#       <td>2</td>
#       <td>0.067</td>
#       <td>0.167</td>
#     </tr>
#     <tr>
#       <td>26.1</td>
#       <td>1</td>
#       <td>0.033</td>
#       <td>0.200</td>
#     </tr>
#     <tr>
#       <td>26.9</td>
#       <td>2</td>
#       <td>0.067</td>
#       <td>0.267</td>
#     </tr>
#     <tr>
#       <td>27.0</td>
#       <td>1</td>
#       <td>0.033</td>
#       <td>0.300</td>
#     </tr>
#     <tr>
#       <td>27.4</td>
#       <td>1</td>
#       <td>0.033</td>
#       <td>0.333</td>
#     </tr>
#     <tr>
#       <td>28.0</td>
#       <td>1</td>
#       <td>0.033</td>
#       <td>0.367</td>
#     </tr>
#     <tr>
#       <td>28.1</td>
#       <td>2</td>
#       <td>0.067</td>
#       <td>0.433</td>
#     </tr>
#     <tr>
#       <td>28.5</td>
#       <td>1</td>
#       <td>0.033</td>
#       <td>0.467</td>
#     </tr>
#     <tr>
#       <td>28.7</td>
#       <td>1</td>
#       <td>0.033</td>
#       <td>0.500</td>
#     </tr>
#     <tr>
#       <td>29.5</td>
#       <td>1</td>
#       <td>0.033</td>
#       <td>0.533</td>
#     </tr>
#     <tr>
#       <td>29.6</td>
#       <td>1</td>
#       <td>0.033</td>
#       <td>0.567</td>
#     </tr>
#     <tr>
#       <td>29.9</td>
#       <td>2</td>
#       <td>0.067</td>
#       <td>0.633</td>
#     </tr>
#     <tr>
#       <td>30.5</td>
#       <td>1</td>
#       <td>0.033</td>
#       <td>0.667</td>
#     </tr>
#     <tr>
#       <td>30.7</td>
#       <td>1</td>
#       <td>0.033</td>
#       <td>0.700</td>
#     </tr>
#     <tr>
#       <td>31.1</td>
#       <td>1</td>
#       <td>0.033</td>
#       <td>0.733</td>
#     </tr>
#     <tr>
#       <td>31.4</td>
#       <td>1</td>
#       <td>0.033</td>
#       <td>0.767</td>
#     </tr>
#     <tr>
#       <td>31.8</td>
#       <td>1</td>
#       <td>0.033</td>
#       <td>0.800</td>
#     </tr>
#     <tr>
#       <td>32.1</td>
#       <td>2</td>
#       <td>0.067</td>
#       <td>0.867</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Aquí va un histograma")
# Out:
# Aquí va un histograma

# %%
plt.figure(figsize = (12, 6)) # Ancho, largo del grafico
marcas_clase = [20.2, 21.6, 23.5, 24.8, 26.1, 26.9, 27.0, 27.4, 28.0, 28.1, 28.5, 28.7, 29.5, 29.6, 29.9, 30.5, 30.7, 31.1, 31.4, 31.8, 32.]#Datos del eje X
# frecuencia =[0.5, 0.15, 0.20, 0.20, 0.10, 0.30,] #Datos del eje Y
frecuencia =[0.033, 0.033, 0.033, 0.067, 0.033, 0.067, 0.033, 0.033, 0.033, 0.067, 0.033, 0.033, 0.033, 0.033, 0.067, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.067, 0.033, 0.033, 0.033, 0.033, 0.067] #Datos del eje Y

# Ajuste en las listas para generar el poligino de frecuencia
datos_x = [0] + marcas_clase 
datos_y = [0] + frecuencia 

#Leyendas para las marcas de clase
marcas_textos = []


# Poligono de frecuencia con:
# - Estilo de line puntedo ( linewidth = 5, color = "r", linestyle = ":"). https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html
# - Marcador con forma triangular (marker = "v"). https://matplotlib.org/stable/api/markers_api.html
plt.plot(datos_x, datos_y,
        linewidth = 5, color = "r", linestyle = ":",
        marker = "v", markersize = 15, markeredgecolor = "b", markerfacecolor = "y")

plt.xticks(marcas_clase , marcas_textos, fontsize= 15, rotation= 45)# Cambio de las marcas de clese del eje x de número a texto.
plt.title("Ojiva", fontsize = 40) # Titulo
plt.xlabel("Marcas de clase", fontsize = 25) # Etiqueta eje X
plt.ylabel("Frecuencia relativa", fontsize = 25) # Etiqueta eje Y
plt.grid(True)#Cuatricula
# Out:
# Aquí va una ojiva
